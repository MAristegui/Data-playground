# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
athletes_df = pd.read_csv('athlete_events.csv')
noc_df = pd.read_csv('country_definitions.csv')

# %%
merged_df = pd.merge(athletes_df, noc_df, on='NOC', how='left')
merged_df = merged_df.drop('notes', axis=1)
merged_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region
# 0       Basketball Men's Basketball   NaN        China
# 1      Judo Men's Extra-Lightweight   NaN        China
# 2           Football Men's Football   NaN      Denmark
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 4  Speed Skating Women's 500 metres   NaN  Netherlands

# %%
# Analyze and visualize the % of athletes who were female over time.

# %%
countsFem = merged_df.groupby(['Year', 'Sex'])['ID'].count().unstack()
countsFem['female_percent'] = countsFem['F'] / (countsFem['F'] + countsFem['M']) * 100

# %%
ax = countsFem['female_percent'].plot(kind='line', figsize=(10, 6), color='purple')
ax.set_xlabel('Year')
ax.set_ylabel('% Female athletes')
ax.set_title('Trend of the percentage of female athletes over time')
plt.show()

# %%
countsMale = merged_df.groupby(['Year', 'Sex'])['ID'].count().unstack()
countsMale['male_percent'] = countsMale['M'] / (countsMale['M'] + countsFem['F']) * 100

# %%
ax = countsMale['male_percent'].plot(kind='line', figsize=(10, 6), color='purple')
ax.set_xlabel('Year')
ax.set_ylabel('% Male athletes')
ax.set_title('Trend of the percentage of male athletes over time')
plt.show()

# %%
counts = merged_df.groupby(['Year', 'Sex'])['ID'].count().unstack()
counts['female_percent'] = counts['F'] / (counts['F'] + counts['M']) * 100
counts['male_percent'] = counts['M'] / (counts['F'] + counts['M']) * 100

# %%
ax = counts[['female_percent', 'male_percent']].plot(kind='line', figsize=(10, 6), color=['purple', 'blue'])
ax.set_xlabel('Year')
ax.set_ylabel('% Athletes')
ax.set_title('Trend of the percentage of female and male athletes over time')
plt.show()

# %%
merged_df['Games'] = merged_df['Games'].str.replace('\d{4} ', '')
merged_df.head()
# Out:
# C:\Users\Chise\AppData\Local\Temp\ipykernel_36720\943489102.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   merged_df['Games'] = merged_df['Games'].str.replace('\d{4} ', '')
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC   Games  Year  Season       City          Sport  \
# 0  CHN  Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  Summer  2012  Summer     London           Judo
# 2  DEN  Summer  1920  Summer  Antwerpen       Football
# 3  DEN  Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region
# 0       Basketball Men's Basketball   NaN        China
# 1      Judo Men's Extra-Lightweight   NaN        China
# 2           Football Men's Football   NaN      Denmark
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 4  Speed Skating Women's 500 metres   NaN  Netherlands

# %%
# Compare and contrast the summer and the winter games

# %%
# How many athletes compete?

# %%
summer_df = merged_df[merged_df['Season'] == 'Summer']
winter_df = merged_df[merged_df['Season'] == 'Winter']

summer_counts = summer_df.groupby('Year')['ID'].count()
winter_counts = winter_df.groupby('Year')['ID'].count()

# %%
plt.figure(figsize=(16, 6))

plt.plot(summer_counts.index, summer_counts.values, label='Summer')
plt.plot(winter_counts.index, winter_counts.values, label='Winter')

plt.legend()
plt.title('Number of athletes per Olympic Games and year')
plt.xlabel('Year')
plt.ylabel('Number of athletes')

plt.show()

# %%
# How many countries compete?

# %%
summer_country_counts = summer_df.groupby('Year')['NOC'].nunique()
winter_country_counts = winter_df.groupby('Year')['NOC'].nunique()

# %%
plt.figure(figsize=(16, 6))

plt.plot(summer_country_counts.index, summer_country_counts.values, label='Summer')
plt.plot(winter_country_counts.index, winter_country_counts.values, label='Winter')

plt.legend()
plt.title('Number of countries per Olympic Games and year')
plt.xlabel('Year')
plt.ylabel('Number of countries')

plt.show()

# %%
# How many events are there?

# %%
summer_event_counts = summer_df.groupby('Year')['Event'].nunique()
winter_event_counts = winter_df.groupby('Year')['Event'].nunique()

# %%
plt.figure(figsize=(16, 6))

plt.plot(summer_event_counts.index, summer_event_counts.values, label='Summer')
plt.plot(winter_event_counts.index, winter_event_counts.values, label='Winter')

plt.legend()
plt.title('Number of events per Olympic Games and year')
plt.xlabel('Year')
plt.ylabel('Number of events')

plt.show()

# %%
# Analyze and visualize country-level trends

# %%
# Which countries send the most athletes to the olympics?

# %%
country_counts = merged_df.groupby('NOC')['Name'].nunique()
top_countries = country_counts.sort_values(ascending=False)[:10]

# %%
plt.bar(top_countries.index, top_countries.values)

plt.title('Top 10 countries with the most athletes in the Olympic Games')
plt.xlabel('Country')
plt.ylabel('Number of athletes')

plt.xticks(rotation=45)

plt.show()

# %%
# Do they also tend to win the most medals?

# %%
athletes_by_country = athletes_df.groupby(['NOC', 'Year', 'Season'])['ID'].nunique().reset_index()
athletes_by_country = athletes_by_country.rename(columns={'ID': 'Num Athletes'})
max_athletes = athletes_by_country.groupby(['NOC', 'Season','Year'])['Num Athletes'].max().reset_index()

top_n_countries = 10 # Por ejemplo, analizamos los 10 países que envían más atletas
top_athlete_countries = max_athletes.groupby('Season').apply(lambda x: x.nlargest(top_n_countries, 'Num Athletes')).reset_index(drop=True)

# %%
medals_by_country = athletes_df.groupby(['NOC', 'Year', 'Season'])['Medal'].apply(lambda x: x[x != 'NA'].count()).reset_index(name='Num Medals')
max_medals = medals_by_country.groupby(['NOC', 'Season','Year'])['Num Medals'].max().reset_index()
top_medal_countries = max_medals.groupby('Season').apply(lambda x: x.nlargest(top_n_countries, 'Num Medals')).reset_index(drop=True)

# %%
medals_df = merged_df[merged_df['Medal'].notnull()]
medals_df = medals_df.drop(medals_df[medals_df == 'NA'].dropna(how='all').index)
medals_df.dropna(subset=['Medal'], inplace=True)
medals_by_country = medals_df.groupby('region')['Medal'].count()
top_countries = medals_by_country.sort_values(ascending=False).head(10)

# %%
plt.bar(top_countries.index, top_countries.values)
plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Number of medals')
plt.title('Top 10 countries with the most medals in the Olympic Games')
plt.show()

# %%
# How have these trends changed over time?

# %%
top_10_countries = medals_df.groupby('NOC')['Medal'].count().nlargest(10).index.tolist()
medals_top_10 = medals_df[medals_df['NOC'].isin(top_10_countries)]

medals_pivot = medals_top_10.pivot_table(values='Medal', index='Year', columns='NOC', aggfunc='count')

# %%
medals_pivot.plot(kind='line', figsize=(10, 6))

plt.title('Medals won by the top 10 countries with the most medals overall')
plt.xlabel('Year')
plt.ylabel('Number of medals')

plt.show()

# %%
ax = medals_pivot.plot(kind='line', figsize=(10, 6))
plt.xlim(1986, 2016)

ax.set_title('Medals won by the top 10 countries with the most medals overall in the last 30 years')
ax.set_xlabel('Year')
ax.set_ylabel('Number of medals')

plt.show()

# %%
# Medal count for each country in every sport

# %%
import seaborn as sns

# %%
top_countries = medals_df.groupby('region')['Medal'].count().nlargest(20).index.tolist()
top_sports = medals_df.groupby('Sport')['Medal'].count().nlargest(20).index.tolist()

medals_pivot = medals_df.pivot_table(values='Medal', index='region', columns='Sport', aggfunc='count')
medals_pivot = medals_pivot.loc[top_countries, top_sports]

# %%
sns.heatmap(medals_pivot, cmap='YlGnBu')

plt.title('Number of medals won by each country in each sport (top 20)')
plt.xlabel('Sport')
plt.ylabel('Country')
plt.show()

# %%
# Breakdown of age groups per sport

# %%
top_15_sports = merged_df.groupby('Sport')['Medal'].count().nlargest(15).index.tolist()
sports_top_15 = merged_df[merged_df['Sport'].isin(top_15_sports)]

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(12, 8))
sns.violinplot(x="Sport", y="Age", data=sports_top_15, palette="muted")

plt.xticks(rotation=90)

plt.title("Age distribution by sport (top 15)")
plt.xlabel("Sport")
plt.ylabel("Age")
plt.show()

# %%
# Most popular locations for hosting the Olympic Games

# %%
import folium

# %%
merged_df.dropna(subset=['City'], inplace=True)
cities_df = pd.read_csv('worldcities.csv', usecols=['city', 'lat', 'lng'])

olympic_cities_df = merged_df[['City']].drop_duplicates()
olympic_cities_df = pd.merge(olympic_cities_df, cities_df, left_on='City', right_on='city', how='left')

olympic_cities_df.drop(columns='city', inplace=True)
olympic_cities_df.dropna(subset=['lat', 'lng'], inplace=True)

# %%
m = folium.Map(location=[50, 10], zoom_start=4)

for index, row in olympic_cities_df.iterrows():
    folium.Marker([row['lat'], row['lng']], popup=row['City']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f09755496c4377af1d09d11bb77cd1c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f09755496c4377af1d09d11bb77cd1c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f09755496c4377af1d09d11bb77cd1c2 = L.map(
#                 &quot;map_f09755496c4377af1d09d11bb77cd1c2&quot;,
#                 {
#                     center: [50.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdfd558fb4c0af900f4e7c6f101a89b8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c2);
#
#
#             var marker_665d4ad049b0e418cecf78f121c68e5e = L.marker(
#                 [41.3825, 2.1769],
#                 {}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c2);
#
#
#         var popup_a72a3a2c2e279591be12e48667d46038 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b45d7ab453766cc34be593c90e1b3d1 = $(`&lt;div id=&quot;html_4b45d7ab453766cc34be593c90e1b3d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barcelona&lt;/div&gt;`)[0];
#                 popup_a72a3a2c2e279591be12e48667d46038.setContent(html_4b45d7ab453766cc34be593c90e1b3d1);
#
#
#
#         marker_665d4ad049b0e418cecf78f121c68e5e.bindPopup(popup_a72a3a2c2e279591be12e48667d46038)
#         ;
#
#
#
#
#             var marker_6f922a6f10e3eaf05aa47bfb005d6aaf = L.marker(
#                 [10.1333, -64.6833],
#                 {}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c2);
#
#
#         var popup_89b011e48a43e608e954ce57766a63c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6463b675e5d15d14c5570d9c4391f45 = $(`&lt;div id=&quot;html_d6463b675e5d15d14c5570d9c4391f45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barcelona&lt;/div&gt;`)[0];
#                 popup_89b011e48a43e608e954ce57766a63c3.setContent(html_d6463b675e5d15d14c5570d9c4391f45);
#
#
#
#         marker_6f922a6f10e3eaf05aa47bfb005d6aaf.bindPopup(popup_89b011e48a43e608e954ce57766a63c3)
#         ;
#
#
#
#
#             var marker_2576108f83e9eb573108d2fde38dcb8f = L.marker(
#                 [12.8694, 124.1419],
#                 {}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c2);
#
#
#         var popup_0f87fe09f5a2723e20b5f52bd7e4e8a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_362e71e293254dcd848b007afdd0be8b = $(`&lt;div id=&quot;html_362e71e293254dcd848b007afdd0be8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barcelona&lt;/div&gt;`)[0];
#                 popup_0f87fe09f5a2723e20b5f52bd7e4e8a7.setContent(html_362e71e293254dcd848b007afdd0be8b);
#
#
#
#         marker_2576108f83e9eb573108d2fde38dcb8f.bindPopup(popup_0f87fe09f5a2723e20b5f52bd7e4e8a7)
#         ;
#
#
#
#
#             var marker_81a26090e751e010fda4f279ca4d38aa = L.marker(
#                 [51.5072, -0.1275],
#                 {}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c2);
#
#
#         var popup_f8db20eaec9f34c6c6cc5fe0fc1d1472 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6bfd4c4aeff7c885fbe7a079a1aeaa7 = $(`&lt;div id=&quot;html_c6bfd4c4aeff7c885fbe7a079a1aeaa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London&lt;/div&gt;`)[0];
#                 popup_f8db20eaec9f34c6c6cc5fe0fc1d1472.setContent(html_c6bfd4c4aeff7c885fbe7a079a1aeaa7);
#
#
#
#         marker_81a26090e751e010fda4f279ca4d38aa.bindPopup(popup_f8db20eaec9f34c6c6cc5fe0fc1d1472)
#         ;
#
#
#
#
#             var marker_9489e95fbb88c942d1e76201b93599e2 = L.marker(
#                 [42.9836, -81.2497],
#                 {}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c2);
#
#
#         var popup_e945386cf95214ec371137d5f689d970 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef7ac834968f21ea2e9a2555ed01b436 = $(`&lt;div id=&quot;html_ef7ac834968f21ea2e9a2555ed01b436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London&lt;/div&gt;`)[0];
#                 popup_e945386cf95214ec371137d5f689d970.setContent(html_ef7ac834968f21ea2e9a2555ed01b436);
#
#
#
#         marker_9489e95fbb88c942d1e76201b93599e2.bindPopup(popup_e945386cf95214ec371137d5f689d970)
#         ;
#
#
#
#
#             var marker_feb2e9ca52ce71d598dd3ab5b1b9363b = L.marker(
#                 [39.8935, -83.4375],
#                 {}
#             ).addTo(map_f09755496c4377af1d09d11bb77cd1c

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(location=[0, 0], zoom_start=2)
city_counts = merged_df["City"].value_counts().to_dict()

# %%
heat_layer = folium.FeatureGroup(name="Heatmap")

weights = [city_counts.get(city, 0) for city in olympic_cities_df["City"].tolist()]

# %%
heat_map = folium.plugins.HeatMap(
    data=list(zip(olympic_cities_df['lat'], olympic_cities_df['lng'], weights)),
    name="Heatmap"
)

heat_map.add_to(heat_layer)

# %%
heat_layer.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_267463e77e2fb752b0bd8bf0d2fa59b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_267463e77e2fb752b0bd8bf0d2fa59b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_267463e77e2fb752b0bd8bf0d2fa59b6 = L.map(
#                 &quot;map_267463e77e2fb752b0bd8bf0d2fa59b6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6e4cc8374134207c4c4d8418ddecbcb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_267463e77e2fb752b0bd8bf0d2fa59b6);
#
#
#             var feature_group_110d9180acc4df81c13fa10d368191b0 = L.featureGroup(
#                 {}
#             ).addTo(map_267463e77e2fb752b0bd8bf0d2fa59b6);
#
#
#             var heat_map_afef7dcdbbc006c5ac2a84e29e226999 = L.heatLayer(
#                 [[41.3825, 2.1769, 12977], [10.1333, -64.6833, 12977], [12.8694, 124.1419, 12977], [51.5072, -0.1275, 22426], [42.9836, -81.2497, 22426], [39.8935, -83.4375, 22426], [48.8567, 2.3522, 7169], [33.6688, -95.546, 7169], [36.2933, -88.3065, 7169], [38.2016, -84.2718, 7169], [39.6148, -87.6903, 7169], [51.05, -114.0667, 2639], [34.2633, -86.2108, 3436], [45.6758, 6.3925, 3436], [61.1167, 10.4667, 3160], [34.1141, -118.4068, 12423], [40.7776, -111.9311, 4109], [22.61, 88.4, 4109], [60.1708, 24.9375, 8270], [-33.8678, 151.21, 13821], [33.7628, -84.422, 13780], [59.3294, 18.0686, 4338], [43.5853, 39.7203, 4891], [36.6486, 138.1947, 3605], [39.904, 116.4075, 13602], [-22.9111, -43.2056, 13688], [47.2683, 11.3933, 3639], [43.8564, 18.4131, 2134], [19.4333, -99.1333, 8588], [48.1375, 11.575, 10304], [37.56, 126.99, 12037], [52.52, 13.405, 6506], [41.6114, -72.7758, 6506], [44.4869, -71.2599, 6506], [59.9133, 10.7389, 1088], [-37.8142, 144.9631, 4829], [28.1086, -80.6627, 4829], [26.4166, -99.0061, 8119], [-26.5733, 148.7869, 8119], [52.3728, 4.8936, 4992], [42.942, -74.1906, 4992], [37.6567, 69.6292, 7191], [35.6897, 139.6922, 7702], [49.25, -123.1, 4402], [45.6366, -122.5967, 4402], [45.1715, 5.7224, 1891], [43.0667, 141.35, 1655], [38.6359, -90.2451, 1301], [47.5, 11.0833, 895]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(feature_group_110d9180acc4df81c13fa10d368191b0);
#
#
#             var layer_control_6e6a0bcad8b2176675a4585a84085236 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a6e4cc8374134207c4c4d8418ddecbcb,
#                 },
#                 overlays :  {
#                     &quot;Heatmap&quot; : feature_group_110d9180acc4df81c13fa10d368191b0,
#                 },
#             };
#             L.control.layers(
#                 layer_control_6e6a0bcad8b2176675a4585a84085236.base_layers,
#                 layer_control_6e6a0bcad8b2176675a4585a84085236.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_267463e77e2fb752b0bd8bf0d2fa59b6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
